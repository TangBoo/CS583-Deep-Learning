# %%
from __future__ import print_function
from __future__ import absolute_import
from __future__ import division
import csv
import pandas as pd
import os
import numpy as np
import augmentation as aug
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Lambda
from keras.layers import Activation
from keras.layers import BatchNormalization
from keras.layers import MaxPooling2D
from keras.layers import GlobalAveragePooling2D
from keras.layers import GlobalMaxPooling2D
from keras.layers import Conv2D
from keras.layers import concatenate
from keras.layers import add
from keras.regularizers import l2
from keras.utils import get_file
from keras.utils.data_utils import get_file
from keras.engine.topology import get_source_inputs
from keras_applications.imagenet_utils import _obtain_input_shape
from keras.applications.imagenet_utils import decode_predictions
from keras import backend as K
# Out:
# Using TensorFlow backend.
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
preprocess_input='preprocess_input'

__all__=['DualPathNetwork', 'DPN92', 'DPN98', 'DPN131', 'DPN107', 'preprocess_input', 'decode_predictions']

# %%
data_path= "C:/Users/xiang/Desktop/rsna-intracranial-hemorrhage-detection-128"
images_path=f'{data_path}/stage_2_train_images'
csv_path=f'{data_path}/stage_2_train.csv'
image_index=os.listdir(f'{data_path}/stage_2_train_images')
image_index=pd.DataFrame(image_index)
image_index=image_index[0].str.slice(stop=12).values

# %%
print(np.shape(image_index))
# Out:
# (755947,)

# %%
def shuffle_data(x):
    rand_indices=np.random.permutation(x.shape[0])
    train_indices=rand_indices[0:650000]
    vali_indices=rand_indices[650000:755940]
    return train_indices,vali_indices

# %%
gener=aug.DataGenerator(data_path,images_path=f'{data_path}/stage_2_train_images',csv_path=f'{data_path}/stage_2_train.csv',
                    num_thread=None,is_train=True)

tr_indices,vali_indices=shuffle_data(image_index)
print('train shape:',np.shape(tr_indices))
print('vali shape:',np.shape(vali_indices))
# Out:
# train shape: (650000,)
# vali shape: (105940,)

# %%
def _initial_conv_block_inception(input, initial_conv_filters, weight_decay=5e-4):
    x = Conv2D(initial_conv_filters, (7, 7), padding='same', use_bias=False, kernel_initializer='he_normal',
               kernel_regularizer=l2(weight_decay), strides=(2, 2))(input)
    x = BatchNormalization(momentum=0.9, epsilon=1e-5)(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)
    return x

# %%
def _bn_relu_conv_block(input, filters, kernel=(3, 3), stride=(1, 1), weight_decay=5e-4):
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1

    x = Conv2D(filters, kernel, padding='same', use_bias=False, kernel_initializer='he_normal',
               kernel_regularizer=l2(weight_decay), strides=stride)(input)
    x = BatchNormalization(axis=channel_axis)(x)
    x = Activation('relu')(x)
    return x

# %%
def _grouped_convolution_block(input, grouped_channels, cardinality, strides, weight_decay=5e-4):
    init = input
    channel_axis = 1 if K.image_data_format() == 'channels_first' else -1
    group_list = []
    if cardinality == 1:
        # with cardinality 1, it is a standard convolution
        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=strides,
                   kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(init)
        x = BatchNormalization(axis=channel_axis)(x)
        x = Activation('relu')(x)
        return x
    for c in range(cardinality):
        x = Lambda(lambda z: z[:, :, :, c * grouped_channels:(c + 1) * grouped_channels]
                   if K.image_data_format() == 'channels_last' else
                   lambda z: z[:, c * grouped_channels:(c + 1) * grouped_channels, :, :])(input)

        x = Conv2D(grouped_channels, (3, 3), padding='same', use_bias=False, strides=strides,
                   kernel_initializer='he_normal', kernel_regularizer=l2(weight_decay))(x)

        group_list.append(x)

    group_merge = concatenate(group_list, axis=channel_axis)
    group_merge = BatchNormalization(axis=channel_axis)(group_merge)
    group_merge = Activation('relu')(group_merge)
    return group_merge

# %%
def _dual_path_block(input, pointwise_filters_a, grouped_conv_filters_b, pointwise_filters_c,
                     filter_increment, cardinality, block_type='normal'):
    grouped_channels = int(grouped_conv_filters_b/ cardinality)
    init = concatenate(input, axis=-1) if isinstance(input, list) else input
    if block_type == 'projection':
        stride = (1, 1)
        projection = True
    elif block_type == 'downsample':
        stride = (2, 2)
        projection = True
    elif block_type == 'normal':
        stride = (1, 1)
        projection = False
    else:
        raise ValueError('`block_type` must be one of ["projection", "downsample", "normal"]. Given %s' % block_type)

    if projection:
        projection_path = _bn_relu_conv_block(init, filters=pointwise_filters_c + 2 * filter_increment,
                                              kernel=(1, 1), stride=stride)
        input_residual_path = Lambda(lambda z: z[:, :, :, :pointwise_filters_c]
                                     if K.image_data_format() == 'channels_last' else
                                     z[:, :pointwise_filters_c, :, :])(projection_path)
        input_dense_path = Lambda(lambda z: z[:, :, :, pointwise_filters_c:]
                                  if K.image_data_format() == 'channels_last' else
                                  z[:, pointwise_filters_c:, :, :])(projection_path)
    else:
        input_residual_path = input[0]
        input_dense_path = input[1]

    x = _bn_relu_conv_block(init, filters=pointwise_filters_a, kernel=(1, 1))
    x = _grouped_convolution_block(x, grouped_channels=grouped_channels, cardinality=cardinality, strides=stride)
    x = _bn_relu_conv_block(x, filters=pointwise_filters_c + filter_increment, kernel=(1, 1))

    output_residual_path = Lambda(lambda z: z[:, :, :, :pointwise_filters_c]
                                  if K.image_data_format() == 'channels_last' else
                                  z[:, :pointwise_filters_c, :, :])(x)
    output_dense_path = Lambda(lambda z: z[:, :, :, pointwise_filters_c:]
                               if K.image_data_format() == 'channels_last' else
                               z[:, pointwise_filters_c:, :, :])(x)

    residual_path = add([input_residual_path, output_residual_path])
    dense_path = concatenate([input_dense_path, output_dense_path], axis=-1)

    return [residual_path, dense_path]

# %%
def _create_dpn(nb_classes,img_input,include_top,initial_conv_filters,filter_increment,depth,cardinality=32,width=3,weight_decay=5e-4,pooling=None):
    N=list(depth)
    base_filters=256
    x=_initial_conv_block_inception(img_input,initial_conv_filters,weight_decay)

    filter_inc=filter_increment[0]
    filters=int(cardinality*width)

    for i in range(N[0]-1):
        x=_dual_path_block(x,pointwise_filters_a=filters,grouped_conv_filters_b=filters,pointwise_filters_c=base_filters,filter_increment=filter_inc,
                           cardinality=cardinality,block_type='projection')
    for i in range(N[0]-1):
        x = _dual_path_block(x, pointwise_filters_a=filters,
                             grouped_conv_filters_b=filters,
                             pointwise_filters_c=base_filters,
                             filter_increment=filter_inc,
                             cardinality=cardinality,
                             block_type='normal')
    for k in range(1, len(N)):
        print("BLOCK %d" % (k + 1))
        filter_inc = filter_increment[k]
        filters *= 2
        base_filters *= 2

        x = _dual_path_block(x, pointwise_filters_a=filters,
                             grouped_conv_filters_b=filters,
                             pointwise_filters_c=base_filters,
                             filter_increment=filter_inc,
                             cardinality=cardinality,
                             block_type='downsample')

        for i in range(N[k] - 1):
            x = _dual_path_block(x, pointwise_filters_a=filters,
                                 grouped_conv_filters_b=filters,
                                 pointwise_filters_c=base_filters,
                                 filter_increment=filter_inc,
                                 cardinality=cardinality,
                                 block_type='normal')

    x = concatenate(x, axis=-1)
    if include_top:
        avg = GlobalAveragePooling2D()(x)
        max = GlobalMaxPooling2D()(x)
        x = add([avg,max])
        x = Lambda(lambda z: 0.5 * z)(x)
        x = Dense(nb_classes, use_bias=False,kernel_regularizer=l2(weight_decay),
                  kernel_initializer='he_normal', activation='sigmoid')(x)
    else:
        if pooling == 'avg':
            x = GlobalAveragePooling2D()(x)
            x= Dense(units=nb_classes,
                 activation='sigmoid',
                 kernel_initializer='he_normal',
                 kernel_regularizer=l2(weight_decay))(x)

        elif pooling == 'max':
            x = GlobalMaxPooling2D()(x)
        elif pooling == 'max-avg':
            a = GlobalMaxPooling2D()(x)
            b = GlobalAveragePooling2D()(x)
            x = add([a, b])
            x = Lambda(lambda z: 0.5 * z)(x)

    return x

# %%
def DualPathNetwork(input_shape=None,initial_conv_filters=64,depth=[3, 4, 20, 3],filter_increment=[16, 32, 24, 128],
                    cardinality=32,width=3,weight_decay=0,include_top=True,weights=None,input_tensor=None,pooling=None,classes=6):
    if weights not in {'imagenet', None}:
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or `imagenet` '
                         '(pre-training on ImageNet).')
    assert len(depth)==len(filter_increment)
    input_shape=_obtain_input_shape(input_shape,default_size=224,min_size=28,data_format=K.image_data_format(),require_flatten=include_top)

    if input_tensor is None:
        img_input=Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input=Input(tensor=input_tensor,shape=input_shape)
        else:
            img_input=input_tensor
    x = _create_dpn(classes, img_input, include_top, initial_conv_filters,
                    filter_increment, depth, cardinality, width, weight_decay, pooling)
    if input_tensor is not None:
        inputs=get_source_inputs(input_tensor)
    else:
        inputs=img_input

    model=Model(inputs,x,name='DPN')

    return model

# %%
def DPN92(input_shape=None,
          include_top=True,
          weights=None,
          input_tensor=None,
          pooling=None,
          classes=6):
    return DualPathNetwork(input_shape, include_top=include_top, weights=weights, input_tensor=input_tensor,
                           pooling=pooling, classes=classes)


def DPN98(input_shape=None,
          include_top=True,
          weights=None,
          input_tensor=None,
          pooling=None,
          classes=6):
    return DualPathNetwork(input_shape, initial_conv_filters=96, depth=[3, 6, 20, 3], filter_increment=[16, 32, 32, 128],
                           cardinality=40, width=4, include_top=include_top, weights=weights, input_tensor=input_tensor,
                           pooling=pooling, classes=classes)


def DPN131(input_shape=None,
           include_top=True,
           weights=None,
           input_tensor=None,
           pooling=None,
           classes=6):
    return DualPathNetwork(input_shape, initial_conv_filters=128, depth=[4, 8, 28, 3], filter_increment=[16, 32, 32, 128],
                           cardinality=40, width=4, include_top=include_top, weights=weights, input_tensor=input_tensor,
                           pooling=pooling, classes=classes)


def DPN107(input_shape=None,
           include_top=True,
           weights=None,
           input_tensor=None,
           pooling=None,
           classes=6):
    return DualPathNetwork(input_shape, initial_conv_filters=128, depth=[4, 8, 20, 3], filter_increment=[20, 64, 64, 128],
                           cardinality=50, width=4, include_top=include_top, weights=weights, input_tensor=input_tensor,
                           pooling=pooling, classes=classes)

# %%
image_size=128
iterations=10000
img_rows, img_cols = 128,128
img_channels = 1
num_classes= 6
batch_size=25        
epochs=20
weight_decay= 1e-4

# %%
model =DPN92((img_rows,img_cols,1),include_top=False,classes=6,pooling='avg')
model.summary()
# Out:
# BLOCK 2
# BLOCK 3
# BLOCK 4
# Model: "DPN"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 64, 64, 64)   3136        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 64, 64, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 64, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 96)   6144        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 96)   384         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 96)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_29 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_30 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_31 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_32 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_33 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# lambda_34 (Lambda)              (None, 32, 32, 3)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 3)    81          lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 32, 32, 3)    81          lambda_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 3)    81          lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 3)    81          lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 3)    81          lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 3)    81          lambda_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 3)    81          lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 3)    81          lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 3)    81          lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 32, 32, 3)    81          lambda_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 32, 32, 3)    81          lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 32, 32, 3)    81          lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 32, 32, 3)    81          lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 3)    81          lambda_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 3)    81          lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 32, 32, 3)    81          lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 32, 32, 3)    81          lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 32, 32, 3)    81          lambda_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 3)    81          lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 3)    81          lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 32, 32, 3)    81          lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 3)    81          lambda_24[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 32, 32, 3)    81          lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 32, 32, 3)    81          lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 32, 32, 3)    81          lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 32, 32, 3)    81          lambda_28[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 32, 32, 3)    81          lambda_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 32, 32, 3)    81          lambda_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 32, 32, 3)    81          lambda_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 3)    81          lambda_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 32, 32, 3)    81          lambda_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 32, 32, 3)    81          lambda_34[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 96)   0           conv2d_4[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
#                                                                  conv2d_7[0][0]
#                                                                  conv2d_8[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_10[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_14[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_16[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
#                                                                  conv2d_19[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_21[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_23[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_26[0][0]
#                                                                  conv2d_27[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_29[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
#                                                                  conv2d_32[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 96)   384         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 96)   0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 288)  18432       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 32, 32, 272)  26112       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 288)  1152        conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 272)  1088        conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 288)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 272)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_35 (Lambda)              (None, 32, 32, 256)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 32, 32, 32)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# lambda_36 (Lambda)              (None, 32, 32, 16)   0           activation_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 256)  0           lambda_1[0][0]
#                                                                  lambda_35[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 48)   0           lambda_2[0][0]
#                                                                  lambda_36[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 304)  0           add_1[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 96)   29184       concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 96)   384         conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 32, 32, 96)   0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# lambda_39 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_40 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_41 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_42 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_43 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_44 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_45 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_46 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_47 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_48 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_49 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_50 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_51 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_52 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_53 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_54 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_55 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_56 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_65 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_66 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_67 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_68 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_69 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# lambda_70 (Lambda)              (None, 32, 32, 3)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 3)    81          lambda_39[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 32, 32, 3)    81          lambda_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 32, 32, 3)    81          lambda_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 32, 32, 3)    81          lambda_42[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 32, 32, 3)    81          lambda_43[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 32, 32, 3)    81          lambda_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 32, 32, 3)    81          lambda_45[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 32, 32, 3)    81          lambda_46[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 32, 32, 3)    81          lambda_47[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 32, 32, 3)    81          lambda_48[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 32, 32, 3)    81          lambda_49[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 32, 32, 3)    81          lambda_50[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 3)    81          lambda_51[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 3)    81          lambda_52[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 3)    81          lambda_53[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 3)    81          lambda_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 3)    81          lambda_55[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 3)    81          lambda_56[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 32, 32, 3)    81          lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 3)    81          lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 3)    81          lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 3)    81          lambda_60[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 3)    81          lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 3)    81          lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 3)    81          lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 3)    81          lambda_64[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 3)    81          lambda_65[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 3)    81          lambda_66[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 3)    81          lambda_67[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 3)    81          lambda_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 3)    81          lambda_69[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 3)    81          lambda_70[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 96)   0           conv2d_39[0][0]
#                                                                  conv2d_40[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_42[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
#                                                                  conv2d_45[0][0]
#                                                                  conv2d_46[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_48[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
#                                                                  conv2d_51[0][0]
#                                                                  conv2d_52[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_54[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
#                                                                  conv2d_57[0][0]
#                                                                  conv2d_58[0][0]
#                                                                  conv2d_59[0][0]
#                                                                  conv2d_60[0][0]
#                                                                  conv2d_61[0][0]
#                                                                  conv2d_62[0][0]
#                                                                  conv2d_63[0][0]
#                                                                  conv2d_64[0][0]
#                                                                  conv2d_65[0][0]
#                                                                  conv2d_66[0][0]
#                                                                  conv2d_67[0][0]
#                                                                  conv2d_68[0][0]
#                                                                  conv2d_69[0][0]
#                                                                  conv2d_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 32, 32, 96)   384         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 32, 32, 96)   0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 288)  87552       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 272)  26112       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 288)  1152        conv2d_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 32, 32, 272)  1088        conv2d_71[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 32, 32, 288)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 32, 32, 272)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# lambda_37 (Lambda)              (None, 32, 32, 256)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_71 (Lambda)              (None, 32, 32, 256)  0           activation_9[0][0]
# __________________________________________________________________________________________________
# lambda_38 (Lambda)              (None, 32, 32, 32)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# lambda_72 (Lambda)              (None, 32, 32, 16)   0           activation_9[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 32, 32, 256)  0           lambda_37[0][0]
#                                                                  lambda_71[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 48)   0           lambda_38[0][0]
#                                                                  lambda_72[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 304)  0           add_2[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 96)   29184       concatenate_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 32, 32, 96)   384         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 32, 32, 96)   0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# lambda_73 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_74 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_75 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_76 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_77 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_78 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_79 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_80 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_81 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_82 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_83 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_84 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_85 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_86 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_87 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_88 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_89 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_90 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_91 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_92 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_93 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_94 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_95 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_96 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_97 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_98 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_99 (Lambda)              (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_100 (Lambda)             (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_101 (Lambda)             (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_102 (Lambda)             (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_103 (Lambda)             (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# lambda_104 (Lambda)             (None, 32, 32, 3)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 3)    81          lambda_73[0][0]
# ...
# __________________________________________________________________________________________________
# lambda_1046 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1047 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1048 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1049 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1050 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1051 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1052 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1053 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1054 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1055 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1056 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1057 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1058 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1059 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1060 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1061 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# lambda_1062 (Lambda)            (None, 4, 4, 24)     0           activation_97[0][0]
# __________________________________________________________________________________________________
# conv2d_1028 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1031[0][0]
# __________________________________________________________________________________________________
# conv2d_1029 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1032[0][0]
# __________________________________________________________________________________________________
# conv2d_1030 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1033[0][0]
# __________________________________________________________________________________________________
# conv2d_1031 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1034[0][0]
# __________________________________________________________________________________________________
# conv2d_1032 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1035[0][0]
# __________________________________________________________________________________________________
# conv2d_1033 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1036[0][0]
# __________________________________________________________________________________________________
# conv2d_1034 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1037[0][0]
# __________________________________________________________________________________________________
# conv2d_1035 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1038[0][0]
# __________________________________________________________________________________________________
# conv2d_1036 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1039[0][0]
# __________________________________________________________________________________________________
# conv2d_1037 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1040[0][0]
# __________________________________________________________________________________________________
# conv2d_1038 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1041[0][0]
# __________________________________________________________________________________________________
# conv2d_1039 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1042[0][0]
# __________________________________________________________________________________________________
# conv2d_1040 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1043[0][0]
# __________________________________________________________________________________________________
# conv2d_1041 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1044[0][0]
# __________________________________________________________________________________________________
# conv2d_1042 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1045[0][0]
# __________________________________________________________________________________________________
# conv2d_1043 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1046[0][0]
# __________________________________________________________________________________________________
# conv2d_1044 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1047[0][0]
# __________________________________________________________________________________________________
# conv2d_1045 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1048[0][0]
# __________________________________________________________________________________________________
# conv2d_1046 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1049[0][0]
# __________________________________________________________________________________________________
# conv2d_1047 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1050[0][0]
# __________________________________________________________________________________________________
# conv2d_1048 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1051[0][0]
# __________________________________________________________________________________________________
# conv2d_1049 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1052[0][0]
# __________________________________________________________________________________________________
# conv2d_1050 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1053[0][0]
# __________________________________________________________________________________________________
# conv2d_1051 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1054[0][0]
# __________________________________________________________________________________________________
# conv2d_1052 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1055[0][0]
# __________________________________________________________________________________________________
# conv2d_1053 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1056[0][0]
# __________________________________________________________________________________________________
# conv2d_1054 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1057[0][0]
# __________________________________________________________________________________________________
# conv2d_1055 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1058[0][0]
# __________________________________________________________________________________________________
# conv2d_1056 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1059[0][0]
# __________________________________________________________________________________________________
# conv2d_1057 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1060[0][0]
# __________________________________________________________________________________________________
# conv2d_1058 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1061[0][0]
# __________________________________________________________________________________________________
# conv2d_1059 (Conv2D)            (None, 4, 4, 24)     5184        lambda_1062[0][0]
# __________________________________________________________________________________________________
# concatenate_91 (Concatenate)    (None, 4, 4, 768)    0           conv2d_1028[0][0]
#                                                                  conv2d_1029[0][0]
#                                                                  conv2d_1030[0][0]
#                                                                  conv2d_1031[0][0]
#                                                                  conv2d_1032[0][0]
#                                                                  conv2d_1033[0][0]
#                                                                  conv2d_1034[0][0]
#                                                                  conv2d_1035[0][0]
#                                                                  conv2d_1036[0][0]
#                                                                  conv2d_1037[0][0]
#                                                                  conv2d_1038[0][0]
#                                                                  conv2d_1039[0][0]
#                                                                  conv2d_1040[0][0]
#                                                                  conv2d_1041[0][0]
#                                                                  conv2d_1042[0][0]
#                                                                  conv2d_1043[0][0]
#                                                                  conv2d_1044[0][0]
#                                                                  conv2d_1045[0][0]
#                                                                  conv2d_1046[0][0]
#                                                                  conv2d_1047[0][0]
#                                                                  conv2d_1048[0][0]
#                                                                  conv2d_1049[0][0]
#                                                                  conv2d_1050[0][0]
#                                                                  conv2d_1051[0][0]
#                                                                  conv2d_1052[0][0]
#                                                                  conv2d_1053[0][0]
#                                                                  conv2d_1054[0][0]
#                                                                  conv2d_1055[0][0]
#                                                                  conv2d_1056[0][0]
#                                                                  conv2d_1057[0][0]
#                                                                  conv2d_1058[0][0]
#                                                                  conv2d_1059[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 4, 4, 768)    3072        concatenate_91[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 4, 4, 768)    0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_1060 (Conv2D)            (None, 4, 4, 2176)   1671168     activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 4, 4, 2176)   8704        conv2d_1060[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 4, 4, 2176)   0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# lambda_1063 (Lambda)            (None, 4, 4, 2048)   0           activation_99[0][0]
# __________________________________________________________________________________________________
# lambda_1064 (Lambda)            (None, 4, 4, 128)    0           activation_99[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 4, 4, 2048)   0           add_30[0][0]
#                                                                  lambda_1063[0][0]
# __________________________________________________________________________________________________
# concatenate_92 (Concatenate)    (None, 4, 4, 640)    0           concatenate_89[0][0]
#                                                                  lambda_1064[0][0]
# __________________________________________________________________________________________________
# concatenate_93 (Concatenate)    (None, 4, 4, 2688)   0           add_31[0][0]
#                                                                  concatenate_92[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_1 (Glo (None, 2688)         0           concatenate_93[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 6)            16134       global_average_pooling2d_1[0][0]
# ==================================================================================================
# Total params: 35,239,942
# Trainable params: 35,124,710
# Non-trainable params: 115,232
# __________________________________________________________________________________________________

# %%
from keras import optimizers
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import ModelCheckpoint
# from keras.preprocessing.image import ImageDataGenerator
# img_input = Input(shape=(img_rows, img_cols, img_channels))
sgd = optimizers.SGD(lr=.1, momentum=0.9, nesterov=True)
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['binary_accuracy'])
# reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.1,patience=10, min_lr=0.001)
checkpointer=ModelCheckpoint(filepath=os.path.join(data_path,'chack_point_weight.hdf5'),save_best_only=True,save_weights_only=True)
# Out:
# WARNING:tensorflow:From c:\users\xiang\.conda\envs\fianl_even\lib\site-packages\tensorflow\python\ops\nn_impl.py:182: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.load_weights(os.path.join(data_path,'my_model_weights.h5'))

# %%
history=model.fit_generator(generator=gener.get_X_batch(image_index[tr_indices],batch_size,image_size,True),steps_per_epoch=iterations,epochs=epochs,callbacks=None,
                            validation_data=gener.get_X_batch(image_index[vali_indices],20,image_size,False),validation_steps=len(vali_indices)//20,class_weight={0:2.,1:1.,2:1.,3:1.,4:1.,5:1.})
print(history)
# Out:
# Epoch 1/20
# 10000/10000 [==============================] - 10533s 1s/step - loss: 0.5861 - binary_accuracy: 0.8841 - val_loss: 0.2654 - val_binary_accuracy: 0.8875
# Epoch 2/20
# 10000/10000 [==============================] - 10436s 1s/step - loss: 0.5853 - binary_accuracy: 0.8843 - val_loss: 0.3838 - val_binary_accuracy: 0.8629
# Epoch 3/20
# 10000/10000 [==============================] - 10431s 1s/step - loss: 0.5850 - binary_accuracy: 0.8844 - val_loss: 0.1625 - val_binary_accuracy: 0.8870
# Epoch 4/20
# 10000/10000 [==============================] - 10425s 1s/step - loss: 0.5857 - binary_accuracy: 0.8842 - val_loss: 0.2382 - val_binary_accuracy: 0.8703
# Epoch 5/20
# 10000/10000 [==============================] - 10415s 1s/step - loss: 0.5827 - binary_accuracy: 0.8851 - val_loss: 0.2923 - val_binary_accuracy: 0.8853
# Epoch 6/20
# 10000/10000 [==============================] - 10408s 1s/step - loss: 0.5830 - binary_accuracy: 0.8848 - val_loss: 0.2387 - val_binary_accuracy: 0.8701
# Epoch 7/20
# 10000/10000 [==============================] - 10400s 1s/step - loss: 0.5838 - binary_accuracy: 0.8849 - val_loss: 0.2600 - val_binary_accuracy: 0.8851
# Epoch 8/20
# 10000/10000 [==============================] - 10425s 1s/step - loss: 0.5846 - binary_accuracy: 0.8847 - val_loss: 0.2682 - val_binary_accuracy: 0.8870
# Epoch 9/20
# 10000/10000 [==============================] - 10411s 1s/step - loss: 0.5841 - binary_accuracy: 0.8850 - val_loss: 0.4663 - val_binary_accuracy: 0.8809
# Epoch 10/20
# 10000/10000 [==============================] - 10403s 1s/step - loss: 0.5837 - binary_accuracy: 0.8847 - val_loss: 0.4584 - val_binary_accuracy: 0.8702
# Epoch 11/20
# 10000/10000 [==============================] - 10381s 1s/step - loss: 0.5816 - binary_accuracy: 0.8857 - val_loss: 0.3146 - val_binary_accuracy: 0.8824
# Epoch 12/20
# 10000/10000 [==============================] - 10404s 1s/step - loss: 0.5851 - binary_accuracy: 0.8844 - val_loss: 0.2462 - val_binary_accuracy: 0.8832
# Epoch 13/20
# 10000/10000 [==============================] - 10391s 1s/step - loss: 0.5825 - binary_accuracy: 0.8854 - val_loss: 0.3254 - val_binary_accuracy: 0.8878
# Epoch 14/20
# 10000/10000 [==============================] - 10400s 1s/step - loss: 0.5831 - binary_accuracy: 0.8848 - val_loss: 0.4406 - val_binary_accuracy: 0.8791
# Epoch 15/20
# 10000/10000 [==============================] - 10397s 1s/step - loss: 0.5823 - binary_accuracy: 0.8853 - val_loss: 0.3028 - val_binary_accuracy: 0.8817
# Epoch 16/20
# 10000/10000 [==============================] - 10401s 1s/step - loss: 0.5808 - binary_accuracy: 0.8859 - val_loss: 0.3319 - val_binary_accuracy: 0.8726
# Epoch 17/20
# 10000/10000 [==============================] - 10419s 1s/step - loss: 0.5809 - binary_accuracy: 0.8858 - val_loss: 0.3480 - val_binary_accuracy: 0.8467
# Epoch 18/20
# 10000/10000 [==============================] - 10331s 1s/step - loss: 0.5832 - binary_accuracy: 0.8855 - val_loss: 0.3145 - val_binary_accuracy: 0.8809
# Epoch 19/20
# 10000/10000 [==============================] - 10343s 1s/step - loss: 0.5824 - binary_accuracy: 0.8857 - val_loss: 0.4260 - val_binary_accuracy: 0.8834
# Epoch 20/20
# 10000/10000 [==============================] - 10350s 1s/step - loss: 0.5820 - binary_accuracy: 0.8858 - val_loss: 0.3759 - val_binary_accuracy: 0.8743
# <keras.callbacks.callbacks.History object at 0x000001BC940FD860>

# %%
test_image_path=f'{data_path}/stage_2_test_images'
test_image_index=os.listdir(f'{data_path}/stage_2_test_images')
test_image_index=pd.DataFrame(test_image_index)
test_image_index=test_image_index[0].str.slice(stop=12).values

# %%
from concurrent.futures import ThreadPoolExecutor as threadPool
from PIL import Image
def load_image(temp_path):
        im = np.array(Image.open(test_image_path+'/'+temp_path+'.png'))
#         print(im)
        return im
        
def get_img(img_paths, img_size):
        p = threadPool()
        X = np.zeros((len(img_paths), img_size, img_size), dtype=np.uint8)
        i = 0
        for future in p.map(load_image, img_paths):
            img = np.resize(future, (img_size, img_size))
#             print(img)
            X[i, :, :] = img
            
            i += 1
        p.shutdown(wait=False)
        return X

# %%
def get_test_batch(X_path,batch_size,img_size):
        try:
            if len(X_path) %batch_size != 0:
                raise Exception("batchSize not match the size of data!")
        except Exception as err:
            print(err)
        else:
            while 1:
                for i in range(0, len(X_path), batch_size):
                    X =(get_img(X_path[i:i + batch_size], img_size))
                    yield np.resize(X/255,(len(X),img_size,img_size,1)).astype('float16')

# %%
test_gener=get_test_batch(test_image_index,16,128)

# %%
submission_result=model.predict_generator(generator=test_gener,steps=len(test_image_index)//16)
print(submission_result)
# Out:
# [[2.05431521e-01 9.48023796e-03 9.07397270e-03 1.95831060e-04
#   3.24777067e-02 1.41400844e-01]
#  [1.64663792e-03 6.85453415e-07 1.40070915e-05 8.64267349e-07
#   7.53790140e-04 3.82810831e-04]
#  [5.88020682e-02 1.93083286e-03 1.04486942e-02 2.00161338e-03
#   4.49567139e-02 1.39557123e-02]
#  ...
#  [2.68132687e-02 2.02324986e-03 4.37593460e-03 9.97781754e-05
#   9.87571478e-03 7.34478235e-03]
#  [8.90582800e-03 1.29044056e-05 7.40289688e-05 3.57627869e-07
#   1.02296472e-03 3.69477272e-03]
#  [3.92246485e-01 5.73506057e-02 6.20033741e-02 2.65708566e-03
#   1.43832713e-01 2.57959127e-01]]

# %%
def evaluation(prob):        
    return max(min(prob,1-pow(10,-15)),pow(10,-15))

# %%
for i in range(len(submission_result)):
    for j in range(len(submission_result[i])):
        submission_result[i,j]=evaluation(submission_result[i,j])

# %%
def read_csv(filename):
            df = pd.read_csv(filename)
            df["ImageID"] = df["ID"].str.slice(stop=12)
            df["Diagnosis"] = df["ID"].str.slice(start=13)
            df = df.loc[:, ["Label", "Diagnosis", "ImageID"]]
            df = df.set_index(['ImageID', 'Diagnosis']).unstack(level=-1)
            return df

# %%
submission_csv=read_csv( 'C:/Users/xiang/Desktop/rsna-intracranial-hemorrhage-detection-128/stage_2_sample_submission.csv')
submission_csv.head()
# Out:
#              Label                                                          \
# Diagnosis      any epidural intraparenchymal intraventricular subarachnoid
# ImageID
# ID_000000e27   0.5      0.5              0.5              0.5          0.5
# ID_000009146   0.5      0.5              0.5              0.5          0.5
# ID_00007b8cb   0.5      0.5              0.5              0.5          0.5
# ID_000134952   0.5      0.5              0.5              0.5          0.5
# ID_000176f2a   0.5      0.5              0.5              0.5          0.5
#
#
# Diagnosis    subdural
# ImageID
# ID_000000e27      0.5
# ID_000009146      0.5
# ID_00007b8cb      0.5
# ID_000134952      0.5
# ID_000176f2a      0.5

# %%
result_dict={}
for i in range(len(test_image_index)):
    result_dict[test_image_index[i]]=submission_result[i]

# %%
for i in submission_csv.index:
    submission_csv.loc[i]=result_dict[i]

# %%
submission_csv = submission_csv.stack().reset_index()
submission_csv.insert(loc=0, column='ID', value=submission_csv['ImageID'].astype(str) + "_" + submission_csv['Diagnosis'])
submission_csv= submission_csv.drop(["ImageID", "Diagnosis"], axis=1)
submission_csv.to_csv('stage_2_sample_DPN3.csv', index=False)
submission_csv.head()
# Out:
#                               ID     Label
# 0               ID_000000e27_any  0.205432
# 1          ID_000000e27_epidural  0.009480
# 2  ID_000000e27_intraparenchymal  0.009074
# 3  ID_000000e27_intraventricular  0.000196
# 4      ID_000000e27_subarachnoid  0.032478

# %%
model.save_weights(os.path.join(data_path,'my_model_weights.h5'))
model.save(os.path.join(data_path,'my_model.h5'))
